# %%
import numpy as np
from glob import glob
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from tensorflow.keras.utils import image_dataset_from_directory
from sklearn.linear_model import LogisticRegression
from skimage.transform import resize
from sklearn.model_selection import train_test_split

# %%
# Get images' names
non_demented = glob('./data/Non_Demented/*.jpg')
mild_demented = glob('./data/Mild_Demented/*.jpg')
moderate_demented = glob('./data/Moderate_Demented/*.jpg')
very_mild_demented = glob('./data/Very_Mild_Demented/*.jpg')

# Note: The current mapping is that 0 = non_demented, 1 = mild_demented, 2 = moderate_demented, and 3 = very_mild_demented.

num_classes = 4
image_size = (108,108,3)

# %%
def view_image(filename):
    img = mpimg.imread(filename)
    img = img[10:118, 10:118]
    plt.imshow(img)
    print(f'Image shape: {img.shape}')

# %%
print(f'Total amount of non_demented: {len(non_demented)}')
view_image(non_demented[0])
# Out:
# Total amount of non_demented: 3200
# Image shape: (108, 108)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [len(non_demented), len(very_mild_demented), len(mild_demented), len(moderate_demented)]
class_names = ['Non Demented', 'Very Mild Demented', 'Mild Demented', 'Moderate Demented']
ax.bar(class_names,size)
plt.show()

# %%
np.set_printoptions(threshold=np.inf)
def extract_feature(dir_path):
    img = mpimg.imread(dir_path)
    img = img[10:118, 10:118] # photoshopping some values to avoid GPU going brrr
    img = img / 255.0  # normalize pixel values
    img = resize(img, (108, 108, 3))  # convert all images to (108x108x3)
    return img

no_ALZ = np.array([extract_feature(filename) for filename in non_demented])
very_mild_ALZ = np.array([extract_feature(filename) for filename in very_mild_demented])
mild_ALZ = np.array([extract_feature(filename) for filename in mild_demented])
moderate_ALZ = np.array([extract_feature(filename) for filename in moderate_demented])
all_data =  np.concatenate((no_ALZ, very_mild_ALZ, mild_ALZ, moderate_ALZ), axis=0)

y = np.array([0] * len(non_demented) + [1] * len(very_mild_demented) + [2] * len(mild_demented) + [3] * len(moderate_demented))
X_train, X_rem, y_train, y_rem = train_test_split(all_data, y, train_size = 0.8)
X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, train_size = 0.5)
print(f"Length of training set: {len(X_train)}")
print(f"Length of validation set: {len(X_valid)}")
print(f"Length of test set: {len(X_test)}")
# Out:
# Length of training set: 5120
# Length of validation set: 640
# Length of test set: 640

# %%
# SVM

# %%
# Neural Networks (CNN)
from tensorflow import keras 
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.advanced_activations import LeakyReLU

# A cool model
# First layer: Convolution with 32 filters of 3x3 squares
# Second layer: leaky RELU for activation
# Third layer: Max of 2x2 squares
# Fourth layer: Convolution with 64 filters of 3x3 squares
# Fifth layer: Leaky again
# Sixth layer: Max of 2x2 squares
# Same thing for 7-9, except 128 filters
# 10th layer: Flatten all 3 channels
# 11th - 13th: Fully connected neural network through Dense

l2_lambda=0.01

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=image_size,padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

model.add(Conv2D(64, (3, 3), activation='linear', kernel_regularizer=tf.keras.regularizers.l2(l=l2_lambda), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

model.add(Conv2D(128, (3, 3), activation='linear', kernel_regularizer=tf.keras.regularizers.l2(l=l2_lambda), padding='same'))
model.add(LeakyReLU(alpha=0.1))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(2, 2),padding='same'))

model.add(Flatten())
model.add(Dense(512, activation='linear', kernel_regularizer=tf.keras.regularizers.l2(l=l2_lambda)))
model.add(LeakyReLU(alpha=0.1))       
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss="sparse_categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=0.001),metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_7 (Conv2D)           (None, 108, 108, 32)      896
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 108, 108, 32)      0
#
#  max_pooling2d_4 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 54, 54, 64)        18496
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 54, 54, 64)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 27, 27, 64)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 46656)             0
#
#  dense_4 (Dense)             (None, 128)               5972096
#
#  leaky_re_lu_8 (LeakyReLU)   (None, 128)               0
#
#  dense_5 (Dense)             (None, 4)                 516
#
# ...
# Total params: 5,992,004
# Trainable params: 5,992,004
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model_train = model.fit(X_train, y_train, batch_size=1600,epochs=20,verbose=1,validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 4/4 [==============================] - 118s 18s/step - loss: 4.3931 - accuracy: 0.4316 - val_loss: 1.4995 - val_accuracy: 0.4906
# Epoch 2/20
# 4/4 [==============================] - 86s 15s/step - loss: 1.3872 - accuracy: 0.4594 - val_loss: 1.1739 - val_accuracy: 0.3578
# Epoch 3/20
# 4/4 [==============================] - 63s 14s/step - loss: 1.1323 - accuracy: 0.4268 - val_loss: 1.0288 - val_accuracy: 0.4953
# Epoch 4/20
# 4/4 [==============================] - 65s 15s/step - loss: 1.0126 - accuracy: 0.5016 - val_loss: 0.9954 - val_accuracy: 0.4938
# Epoch 5/20
# 4/4 [==============================] - 115s 17s/step - loss: 0.9918 - accuracy: 0.5135 - val_loss: 0.9785 - val_accuracy: 0.5047
# Epoch 6/20
# 4/4 [==============================] - 61s 14s/step - loss: 0.9718 - accuracy: 0.5332 - val_loss: 0.9757 - val_accuracy: 0.5406
# Epoch 7/20
# ...

# %%
test_eval = model.evaluate(X_test, y_test)
# Out:
# 20/20 [==============================] - 2s 77ms/step - loss: 0.7495 - accuracy: 0.7000

# %% [markdown]
# # Visualizing performance over iterations
# The model runs for 20 iterations. This section will plot its accuracy and cross-entropy errors over both the training set and validation set during all 20 iterations.

# %%
accuracy = model_train.history['accuracy']
val_accuracy = model_train.history['val_accuracy']
loss = model_train.history['loss']
val_loss = model_train.history['val_loss']
iterations = range(len(accuracy))

plt.plot(iterations, accuracy, 'bo', label='Training accuracy')
plt.plot(iterations, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(iterations, loss, 'bo', label='Training loss')
plt.plot(iterations, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# # Visualizing the filters
# To get a better understanding of what the weights look like inside the filters of a CNN layer, we can plot their weight as grayscale.
# Then, dark will means small weights and white will means large weights.
# In that sense, we can get an intuition of the patterns that each CNN layer is trying to identify.

# %%
# Visualize the filters. Dark = small weights, light = large weights

filters, biases = model.layers[0].get_weights()
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# plot first 18 filters
n_filters, ix = 6, 1
for i in range(n_filters):
    f = filters[:, :, :, i]
    # plot each channel separately
    for j in range(3):
        ax = plt.subplot(n_filters, 3, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.imshow(f[:, :, j], cmap='gray')
        ix += 1
        
plt.show()

# %% [markdown]
# # Visualizing how the filter applies to an example image
# It can be hard to know what exactly all the filters in the CNN layers are trying to extract.
# By applying the same transformation of one layer to an example input, we can see what kind of features each filters are trying to identify (background, certain edges,...)

# %%
# Visualize how the filter apply to an example image

from keras.models import Model
import random
from numpy import expand_dims

filter_model = Model(inputs=model.inputs, outputs=model.layers[0].output)

# get a random image
idx = random.randint(0, len(all_data) - 1)
sample_img = all_data[idx]
plt.imshow(sample_img)
print(f"Showing image #{idx}: {class_names[y[idx]]}")
sample_img = expand_dims(sample_img, axis=0)
feature_map = filter_model.predict(sample_img)

plt.figure()
# Plot on 4x8
ix = 1
for _ in range(8):
    for _ in range(4):
        ax = plt.subplot(square, square, ix)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.imshow(feature_map[0, :, :, ix-1], cmap='gray')
        ix += 1
# show the figure
plt.show()
# Out:
# Showing image #4127: Mild Demented

# %%
# Logistic Regression

# Some activation functions

def cost():
    pass 

# print(X_train.shape)
# print(X_valid.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_valid.shape)
# print(y_test.shape)
# Out:
# (5120, 128, 384)
# (640, 128, 384)
# (640, 128, 384)
# (5120,)
# (640,)
# (640,)

# %% [markdown]
# # For fun and giggle, we add PCA to see how many features are actually relevant
# Since some part of the images are eternally black and is useless, we use PCA to see how much features are actually relevant

# %%
# For more fun, do PCA
from sklearn import decomposition

X_train_pca = X_train.reshape(X_train.shape[0], np.product(X_train.shape[1:]))
pca = decomposition.PCA(250)
X_proj = pca.fit_transform(X_train_pca)
cumulative_variance = np.cumsum(pca.explained_variance_ratio_) * 100

k = np.argmax(cumulative_variance > 80)
print(f"Number of components explaining 80% variance: {k}")

# Plot the cumulative variance
plt.title('Cumulative Explained Variance explained by the components')
plt.ylabel('Cumulative Explained variance')
plt.xlabel('Principal components')
plt.axvline(x=k, color="k", linestyle="--")
plt.axhline(y=80, color="r", linestyle="--")
plt.plot(cumulative_variance)
plt.show()
# Out:
# Number of components explaining 80% variance: 174

# %% [markdown]
# # For fun and meming purpose, showing the average MRI brain scan
# Because we're bored, we decide to average every images and show the "average" MRI brain scan

# %%
# FOR EVEN MORE FUN, get the average brain scan
average_img = np.average(all_data, axis = 0)
plt.imshow(average_img)
